# %%
import os 
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas

# %%
df1=pandas.read_csv("Supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
s1=pandas.read_json("supermarkets.json")
s1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
s3=pandas.read_excel("supermarkets.xlsx", sheet_name=0)
s3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
s5=pandas.read_csv("supermarkets-commas.txt")
s5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
s6=pandas.read_csv("supermarkets-semi-colons.txt",sep=";", header = None)
s6
# Out:
#     0                1              2                 3        4  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#               5          6
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
s6.columns = ["ID", "Address", "City", "Zip", "Country", "Nmae", "Employees"]
s6
# Out:
#    ID          Address           City               Zip  Country  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#            Nmae  Employees
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
s6.set_index("ID")
# Out:
#              City               Zip  Country          Nmae  Employees
# ID
# ID           City             State  Country          Name  Employees
# 1   San Francisco          CA 94114      USA       Madeira          8
# 2   San Francisco          CA 94119      USA   Bready Shop         15
# 3   San Francisco  California 94114      USA   Super River         25
# 4   San Francisco          CA 94114      USA    Ben's Shop         10
# 5   San Francisco        California      USA       Sanchez         12
# 6   San Francisco          CA 94114      USA    Richvalley         20

# %%
s6
# Out:
#                  ID           City               Zip  Country          Nmae  \
# Address
# Address          ID           City             State  Country          Name
# 3666 21st St      1  San Francisco          CA 94114      USA       Madeira
# 735 Dolores St    2  San Francisco          CA 94119      USA   Bready Shop
# 332 Hill St       3  San Francisco  California 94114      USA   Super River
# 3995 23rd St      4  San Francisco          CA 94114      USA    Ben's Shop
# 1056 Sanchez St   5  San Francisco        California      USA       Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114      USA    Richvalley
#
#                  Employees
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
s9 = s6.set_index("ID")

# %%
s9
# Out:
#              City               Zip  Country          Nmae  Employees
# ID
# ID           City             State  Country          Name  Employees
# 1   San Francisco          CA 94114      USA       Madeira          8
# 2   San Francisco          CA 94119      USA   Bready Shop         15
# 3   San Francisco  California 94114      USA   Super River         25
# 4   San Francisco          CA 94114      USA    Ben's Shop         10
# 5   San Francisco        California      USA       Sanchez         12
# 6   San Francisco          CA 94114      USA    Richvalley         20

# %%
s6.set_index("ID", inplace=True)

# %%
s6
# Out:
#              City               Zip  Country          Nmae  Employees
# ID
# ID           City             State  Country          Name  Employees
# 1   San Francisco          CA 94114      USA       Madeira          8
# 2   San Francisco          CA 94119      USA   Bready Shop         15
# 3   San Francisco  California 94114      USA   Super River         25
# 4   San Francisco          CA 94114      USA    Ben's Shop         10
# 5   San Francisco        California      USA       Sanchez         12
# 6   San Francisco          CA 94114      USA    Richvalley         20

# %%
s6
# Out:
#              City               Zip  Country          Nmae  Employees
# ID
# ID           City             State  Country          Name  Employees
# 1   San Francisco          CA 94114      USA       Madeira          8
# 2   San Francisco          CA 94119      USA   Bready Shop         15
# 3   San Francisco  California 94114      USA   Super River         25
# 4   San Francisco          CA 94114      USA    Ben's Shop         10
# 5   San Francisco        California      USA       Sanchez         12
# 6   San Francisco          CA 94114      USA    Richvalley         20

# %%
s7 = s6.set_index("ID")

# %%
s7
# Out:
#             Address           City               Zip  Country          Nmae  \
# ID
# ID          Address           City             State  Country          Name
# 1      3666 21st St  San Francisco          CA 94114      USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#     Employees
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
s7.set_index("Address", inplace=True)
s7
# Out:
#                           City               Zip  Country          Nmae  \
# Address
# Address                   City             State  Country          Name
# 3666 21st St     San Francisco          CA 94114      USA       Madeira
# 735 Dolores St   San Francisco          CA 94119      USA   Bready Shop
# 332 Hill St      San Francisco  California 94114      USA   Super River
# 3995 23rd St     San Francisco          CA 94114      USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California      USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#                  Employees
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
s7
# Out:
#                           City               Zip  Country          Nmae  \
# Address
# Address                   City             State  Country          Name
# 3666 21st St     San Francisco          CA 94114      USA       Madeira
# 735 Dolores St   San Francisco          CA 94119      USA   Bready Shop
# 332 Hill St      San Francisco  California 94114      USA   Super River
# 3995 23rd St     San Francisco          CA 94114      USA    Ben's Shop
# 1056 Sanchez St  San Francisco        California      USA       Sanchez
# 551 Alvarado St  San Francisco          CA 94114      USA    Richvalley
#
#                  Employees
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
r1=pandas.read_json("http://pythonhow.com/supermarkets.json")
r1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
r1=r1.set_index("Address")

# %%
list(r1.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
r1
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
r1.iloc[3,1:4]
# Out:
# City       San Francisco
# State           CA 94114
# Country              USA
# Name: 3995 23rd St, dtype: object

# %%
r1.drop("332 Hill St",0)
# Out:
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
r1=r1.drop("332 Hill St",0)

# %%
r1.drop(r1.columns[0:3],1)
# Out:
#                 Country         Name  Employees
# Address
# 3666 21st St        USA      Madeira          8
# 735 Dolores St      USA  Bready Shop         15
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12
# 551 Alvarado St     USA   Richvalley         20

# %%
len(r1.index)
# Out:
# 5

# %%
r1["Continent"]=r1.shape[0]*["ZAID"]

# %%
r1["yaa"]=r1.shape[0]*["bomya"]

# %%
r1["Continent"]=r1["Country"]+ "," + "North America"

# %%
r1.drop["yaa"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-c0c6ac2f6de0> in <module>
# ----> 1 r1.drop["yaa"]
#
# TypeError: 'method' object is not subscriptable

# %%
r1
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees Continent
# Address
# 3666 21st St             8      ZAID
# 735 Dolores St          15      ZAID
# 3995 23rd St            10      ZAID
# 1056 Sanchez St         12      ZAID
# 551 Alvarado St         20      ZAID

# %%
r1.drop(r1.index[0:4],0)
# Out:
#                  ID           City     State Country        Name  Employees  \
# Address
# 551 Alvarado St   6  San Francisco  CA 94114     USA  Richvalley         20
#
#                          Continent    yaa
# Address
# 551 Alvarado St  USA,North America  bomya

# %%
r1.columns
# Out:
# Index(['ID', 'City', 'State', 'Country', 'Name', 'Employees', 'Continent',
#        'yaa'],
#       dtype='object')

# %%
r1
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees          Continent    yaa
# Address
# 3666 21st St             8  USA,North America  bomya
# 735 Dolores St          15  USA,North America  bomya
# 3995 23rd St            10  USA,North America  bomya
# 1056 Sanchez St         12  USA,North America  bomya
# 551 Alvarado St         20  USA,North America  bomya

# %%
r1["Continent"]=r1["Country"]+ "," + "North America"

# %%
r1
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees          Continent    yaa
# Address
# 3666 21st St             8  USA,North America  bomya
# 735 Dolores St          15  USA,North America  bomya
# 3995 23rd St            10  USA,North America  bomya
# 1056 Sanchez St         12  USA,North America  bomya
# 551 Alvarado St         20  USA,North America  bomya

# %%
r1["Continent"]=r1.shape[0]*["North America"]

# %%
r1
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees      Continent    yaa
# Address
# 3666 21st St             8  North America  bomya
# 735 Dolores St          15  North America  bomya
# 3995 23rd St            10  North America  bomya
# 1056 Sanchez St         12  North America  bomya
# 551 Alvarado St         20  North America  bomya

# %%
r1.shape
# Out:
# (5, 8)

# %%
r1["Continent"]=r1["Country"] + "," + "North America"

# %%
r1
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees          Continent    yaa
# Address
# 3666 21st St             8  USA,North America  bomya
# 735 Dolores St          15  USA,North America  bomya
# 3995 23rd St            10  USA,North America  bomya
# 1056 Sanchez St         12  USA,North America  bomya
# 551 Alvarado St         20  USA,North America  bomya

# %%
r1_t=r1.T

# %%
r1_t
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# ID                         1                  2                  4
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
# yaa                    bomya              bomya              bomya
#
# Address      1056 Sanchez St    551 Alvarado St
# ID                         5                  6
# City           San Francisco      San Francisco
# State             California           CA 94114
# Country                  USA                USA
# Name                 Sanchez         Richvalley
# Employees                 12                 20
# ...

# %%
r1_t["My Address"]=["My City","My Country", 10,7, "My Sate", "My Continent", "My shop", "My office"]

# %%
r1_t
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# ID                         1                  2                  4
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
# yaa                    bomya              bomya              bomya
#
# Address      1056 Sanchez St    551 Alvarado St    My Address
# ID                         5                  6       My City
# City           San Francisco      San Francisco    My Country
# State             California           CA 94114            10
# Country                  USA                USA             7
# ...

# %%
r1_t.drop("ID",0)
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
# yaa                    bomya              bomya              bomya
#
# Address      1056 Sanchez St    551 Alvarado St    My Address
# City           San Francisco      San Francisco    My Country
# State             California           CA 94114            10
# Country                  USA                USA             7
# Name                 Sanchez         Richvalley       My Sate
# Employees                 12                 20  My Continent
# ...

# %%
r1_t=r1_t.drop("ID",0)

# %%
r1_t
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
# yaa                    bomya              bomya              bomya
#
# Address      1056 Sanchez St    551 Alvarado St    My Address
# City           San Francisco      San Francisco    My Country
# State             California           CA 94114            10
# Country                  USA                USA             7
# Name                 Sanchez         Richvalley       My Sate
# Employees                 12                 20  My Continent
# ...

# %%
r1_t.drop("yaa",0)
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# Address      1056 Sanchez St    551 Alvarado St    My Address
# City           San Francisco      San Francisco    My Country
# State             California           CA 94114            10
# Country                  USA                USA             7
# Name                 Sanchez         Richvalley       My Sate
# Employees                 12                 20  My Continent
# Continent  USA,North America  USA,North America       My shop

# %%
r1_t=r1_t.drop("yaa",0)

# %%
r1_t
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# Address      1056 Sanchez St    551 Alvarado St    My Address
# City           San Francisco      San Francisco    My Country
# State             California           CA 94114            10
# Country                  USA                USA             7
# Name                 Sanchez         Richvalley       My Sate
# Employees                 12                 20  My Continent
# Continent  USA,North America  USA,North America       My shop

# %%
r1_t=r1_t.T

# %%
r1_t
# Out:
#                           City       State Country         Name     Employees  \
# Address
# 3666 21st St     San Francisco    CA 94114     USA      Madeira             8
# 735 Dolores St   San Francisco    CA 94119     USA  Bready Shop            15
# 3995 23rd St     San Francisco    CA 94114     USA   Ben's Shop            10
# 1056 Sanchez St  San Francisco  California     USA      Sanchez            12
# 551 Alvarado St  San Francisco    CA 94114     USA   Richvalley            20
# My Address          My Country          10       7      My Sate  My Continent
#
#                          Continent
# Address
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America
# 551 Alvarado St  USA,North America
# My Address                 My shop

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopy

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS(timeout=600)

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.752990821253434, -122.43170235858965, 0.0))

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
type(n)
# Out:
# geopy.location.Location

# %%
import pandas
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+", "+df["City"] + ", "+ df["State"]+ ", " + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"]=df["Address"].apply(nom.geocode)
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0].latitude
# Out:
# 37.7564496899993

# %%
df["Latitude"]=df["Coordinates"].apply(lambda x: x.latitude)
df["Longitude"]=df["Coordinates"].apply(lambda x: x.longitude)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...

# %%
import pandas
z=pandas.read_csv("supermarkets.csv")
z
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20
